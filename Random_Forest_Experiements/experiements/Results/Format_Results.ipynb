# %%
import pandas as pd
from tabulate import tabulate

# %%
BaseFeatureSampleValues = pd.read_csv('BaseFeatureSampleValues.csv', index_col=['Feature Type','Metric'])
BaseFeatureSampleValues = BaseFeatureSampleValues.round(2)
BaseFeatureSampleValues
# Out:
#                              Sample Size: 1  Sample Size: 2  Sample Size: 3  \
# Feature Type      Metric
# numeric           accuracy             0.97            0.97            0.97
#                   precision            0.94            0.94            0.94
#                   recall               0.99            0.99            0.99
#                   f1-score             0.96            0.96            0.96
# categorical       accuracy             0.97            0.97            0.97
#                   precision            0.91            0.91            0.91
#                   recall               0.95            0.95            0.95
#                   f1-score             0.93            0.93            0.93
# datetime          accuracy             1.00            1.00            1.00
#                   precision            0.99            0.99            0.99
#                   recall               0.97            0.97            0.97
# ...

# %%
BaseFeatureSampleValues.to_latex('BaseFeatureSampleValues.tex')

# %%
# print(tabulate(retrained_sampled_df.reset_index(), tablefmt="pipe", headers="keys", showindex=False))

# %%
DescriptiveStatisticSubsetModel = pd.read_csv('DescriptiveStatisticSubsetModel.csv', index_col=['Feature Type','Metric'])
DescriptiveStatisticSubsetModel = DescriptiveStatisticSubsetModel.round(2)
DescriptiveStatisticSubsetModel
# Out:
#                              Subset Proportion: 0.1  Subset Proportion: 0.2  \
# Feature Type      Metric
# numeric           accuracy                     0.97                    0.97
#                   precision                    0.93                    0.93
#                   recall                       0.98                    0.98
#                   f1-score                     0.95                    0.96
# categorical       accuracy                     0.93                    0.94
#                   precision                    0.83                    0.84
#                   recall                       0.89                    0.91
#                   f1-score                     0.86                    0.87
# datetime          accuracy                     1.00                    0.99
#                   precision                    0.98                    0.96
#                   recall                       0.98                    0.96
# ...

# %%
DescriptiveStatisticSubsetModel.to_latex('DescriptiveStatisticSubsetModel.tex')
