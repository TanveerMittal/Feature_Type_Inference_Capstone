# %%
# %load_ext autoreload
# %autoreload 2
import re
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import transformers
from transformers import AdamW
from transformers import AutoModel, BertTokenizerFast
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import sys
sys.path.append('../')
from process_data import *
from models.bert_mlp_v1 import *
from training import train
from evaluation import evaluate
import matplotlib.pyplot as plt

# %%
df_zoo_train, df_zoo_test = load_data("../data")
df_zoo_train.head()
# Out:
#    Record_id Attribute_name        y_act  total_vals  num_nans  %_nans  \
# 0         33           Area  categorical       21477         0     0.0
# 1         33      Area Code  categorical       21477         0     0.0
# 2         33        Element  categorical       21477         0     0.0
# 3         33   Element Code  categorical       21477         0     0.0
# 4         33           Item  categorical       21477         0     0.0
#
#    num_of_dist_val  %_dist_val         mean     std_dev  ...  \
# 0              174    0.810169     0.000000    0.000000  ...
# 1              174    0.810169   125.449411   72.866452  ...
# 2                2    0.009312     0.000000    0.000000  ...
# 3                2    0.009312  5211.687154  146.816661  ...
# 4              115    0.535457     0.000000    0.000000  ...
#
#    mean_stopword_total  stdev_stopword_total mean_char_count stdev_char_count  \
# 0                  0.2                   0.4            10.0         4.816638
# 1                  0.0                   0.0             1.0         0.000000
# 2                  0.0                   0.0             4.0         0.000000
# 3                  0.0                   0.0             4.0         0.000000
# 4                  0.8                   0.4            19.6         2.244994
#
#   mean_whitespace_count stdev_whitespace_count mean_delim_count  \
# 0                   0.4                    0.8              0.4
# 1                   0.0                    0.0              0.0
# 2                   0.0                    0.0              0.0
# 3                   0.0                    0.0              0.0
# 4                   2.0                    0.0              2.0
#
#    stdev_delim_count  is_list  is_long_sentence
# 0                0.8    False             False
# 1                0.0    False             False
# 2                0.0    False             False
# 3                0.0    False             False
# 4                0.0    False             False
#
# [5 rows x 33 columns]

# %%
train_data = preprocess_bert(df_zoo_train)
test_data = preprocess_bert(df_zoo_test)
train_data.head()
# Out:
#                                                 text  \
# 0  Area [SEP] Afghanistan [SEP] Albania [SEP] Alg...
# 1  Area Code [SEP] 2 [SEP] 3 [SEP] 4 [SEP] 7 [SEP] 8
# 2  Element [SEP] Food [SEP] Feed [SEP] Food [SEP]...
# 3  Element Code [SEP] 5142 [SEP] 5521 [SEP] 5142 ...
# 4  Item [SEP] Wheat and products [SEP] Rice (Mill...
#
#                                             features  label
# 0  [21477.0, 0.0, 0.0, 174.0, 0.810169018, 0.0, 0...      1
# 1  [21477.0, 0.0, 0.0, 174.0, 0.810169018, 125.44...      1
# 2  [21477.0, 0.0, 0.0, 2.0, 0.009312288, 0.0, 0.0...      1
# 3  [21477.0, 0.0, 0.0, 2.0, 0.009312288, 5211.687...      1
# 4  [21477.0, 0.0, 0.0, 115.0, 0.535456535, 0.0, 0...      1

# %%
x_train, x_val, y_train, y_val = train_test_split(train_data[['text', "features"]], train_data['label'], 
                                                                    random_state=2018, 
                                                                    test_size=0.2, 
                                                                    stratify=train_data['label'])

# %%
bert = AutoModel.from_pretrained('bert-base-uncased')

# Load the BERT tokenizer
tokenizer = BertTokenizerFast.from_pretrained('bert-base-uncased')
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
device = torch.device("cuda")

# %%
for param in bert.parameters():
    param.requires_grad = False

# %%
train_dataloader, val_dataloader, test_dataloader = init_dataloaders_bert(x_train, y_train, x_val, y_val, test_data)
# Out:
# /home/tamittal/.local/lib/python3.9/site-packages/transformers/tokenization_utils_base.py:2198: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(

# %%
model = BERT_mlp_v1(bert)

model = model.to(device)

# %%
# define the optimizer
optimizer = AdamW(model.parameters(),
                  lr = 1e-7)

# %%
from sklearn.utils.class_weight import compute_class_weight

#compute the class weights
class_weights = compute_class_weight('balanced', np.unique(y_train), y_train)
print("Class Weights:",class_weights)
# Out:
# Class Weights: [0.30349971 0.4756125  1.64413364 3.04022989 7.66666667 1.88088889
#  4.64035088 1.01050621 1.25281231]
# /home/tamittal/.local/lib/python3.9/site-packages/sklearn/utils/validation.py:67: FutureWarning: Pass classes=[0 1 2 3 4 5 6 7 8], y=2190    0
# 2921    0
# 4042    7
# 3603    0
# 6365    0
#        ..
# 4799    8
# 1221    7
# 7337    5
# 4938    1
# 5419    7
# Name: label, Length: 6348, dtype: int64 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "

# %%
weights= torch.tensor(class_weights,dtype=torch.float)
weights = weights.to(device)

# define the loss function
cross_entropy  = nn.NLLLoss(weight=weights) 

# number of training epochs
epochs = 50

# %%
# set initial loss to infinite
best_valid_loss = float('inf')

# empty lists to store training and validation loss of each epoch
train_losses=[]
valid_losses=[]

# %%
#for each epoch
for epoch in range(epochs):
     
    print('\n Epoch {:} / {:}'.format(epoch + 1, epochs))
    
    #train model
    train_loss, _, = train(model, train_dataloader, optimizer, cross_entropy)
    
    #evaluate model
    valid_loss, _, valid_acc = evaluate(model, val_dataloader, cross_entropy, y_val)
    
    #save the best model
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), 'saved_weights.pt')
    
    # append training and validation loss
    train_losses.append(train_loss)
    valid_losses.append(valid_loss)

    print(f'\nTraining Loss: {train_loss:.3f}')
    print(f'Validation Loss: {valid_loss:.3f}')
    print(f'Validation Accuracy: {valid_acc:.3f}')
# Out:
#  Epoch 1 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 5229016007602.849
# Validation Loss: 15457637.041
# Validation Accuracy: 0.560
#
#  Epoch 2 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 273879618302.937
# Validation Loss: 15342799.161
# Validation Accuracy: 0.561
#
#  Epoch 3 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 2402802649964.844
# Validation Loss: 15333868.328
# Validation Accuracy: 0.565
#
#  Epoch 4 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 2560295397433.324
# Validation Loss: 15228663.773
# Validation Accuracy: 0.568
#
#  Epoch 5 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 1629983795951.667
# Validation Loss: 15207324.487
# Validation Accuracy: 0.567
#
#  Epoch 6 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 13911422620126.336
# Validation Loss: 15251708.842
# Validation Accuracy: 0.565
#
#  Epoch 7 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 8262326187324.158
# Validation Loss: 15262744.726
# Validation Accuracy: 0.566
#
#  Epoch 8 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 9060782754568.354
# Validation Loss: 15200872.267
# Validation Accuracy: 0.565
#
#  Epoch 9 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 4431827122383.529
# Validation Loss: 15119950.781
# Validation Accuracy: 0.562
#
#  Epoch 10 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 884636863399.509
# Validation Loss: 15160118.783
# Validation Accuracy: 0.565
#
#  Epoch 11 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 1404665745316.036
# Validation Loss: 15129687.887
# Validation Accuracy: 0.566
#
#  Epoch 12 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 1498202564780.494
# Validation Loss: 15159456.391
# Validation Accuracy: 0.565
#
#  Epoch 13 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 3098323449919.463
# Validation Loss: 15147598.528
# Validation Accuracy: 0.566
#
#  Epoch 14 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 3110033086093.417
# Validation Loss: 15166335.388
# Validation Accuracy: 0.565
#
#  Epoch 15 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 7194827946312.536
# Validation Loss: 15105742.360
# Validation Accuracy: 0.564
#
#  Epoch 16 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 2179178470043.174
# Validation Loss: 15002746.945
# Validation Accuracy: 0.565
#
#  Epoch 17 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 4560007326263.647
# Validation Loss: 14927470.787
# Validation Accuracy: 0.565
#
#  Epoch 18 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 1647991889037.583
# Validation Loss: 14918382.341
# Validation Accuracy: 0.566
#
#  Epoch 19 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 3879894954764.312
# Validation Loss: 14881809.396
# Validation Accuracy: 0.567
#
#  Epoch 20 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 8795083289546.108
# Validation Loss: 14875560.707
# Validation Accuracy: 0.567
#
#  Epoch 21 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 9013784116.449
# Validation Loss: 14693829.087
# Validation Accuracy: 0.568
#
#  Epoch 22 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 2579903785998.459
# Validation Loss: 14612845.945
# Validation Accuracy: 0.569
#
#  Epoch 23 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 1544920731929.362
# Validation Loss: 14722635.712
# Validation Accuracy: 0.572
#
#  Epoch 24 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 1174898895775.889
# Validation Loss: 14690055.142
# Validation Accuracy: 0.572
#
#  Epoch 25 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 2924409970385.386
# Validation Loss: 14776261.024
# Validation Accuracy: 0.572
#
#  Epoch 26 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 29368533416.071
# Validation Loss: 14748299.897
# Validation Accuracy: 0.568
#
#  Epoch 27 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 1297287696518.362
# Validation Loss: 14682491.680
# Validation Accuracy: 0.568
#
#  Epoch 28 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 1241246719288.577
# Validation Loss: 14597866.656
# Validation Accuracy: 0.572
#
#  Epoch 29 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 3417500311656.147
# Validation Loss: 14419906.433
# Validation Accuracy: 0.571
#
#  Epoch 30 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 1344390587585.940
# Validation Loss: 14379759.977
# Validation Accuracy: 0.573
#
#  Epoch 31 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 3336283778563.252
# Validation Loss: 14468424.755
# Validation Accuracy: 0.573
#
#  Epoch 32 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 681420282464.961
# Validation Loss: 14426211.639
# Validation Accuracy: 0.572
#
#  Epoch 33 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 1211961925298.012
# Validation Loss: 14509147.906
# Validation Accuracy: 0.573
#
#  Epoch 34 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 528890706030.916
# Validation Loss: 14530066.992
# Validation Accuracy: 0.572
#
#  Epoch 35 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 2652382732930.402
# Validation Loss: 14412876.909
# Validation Accuracy: 0.572
#
#  Epoch 36 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 7317437550301.947
# Validation Loss: 14428204.139
# Validation Accuracy: 0.572
#
#  Epoch 37 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 1619181850.357
# Validation Loss: 14346058.392
# Validation Accuracy: 0.574
#
#  Epoch 38 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 3092072222348.437
# Validation Loss: 14292081.288
# Validation Accuracy: 0.578
#
#  Epoch 39 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 2689617931832.809
# Validation Loss: 14322538.670
# Validation Accuracy: 0.577
#
#  Epoch 40 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 4291243996413.547
# Validation Loss: 14360074.836
# Validation Accuracy: 0.578
#
#  Epoch 41 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 4236985922785.599
# Validation Loss: 14329478.559
# Validation Accuracy: 0.580
#
#  Epoch 42 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 2006541978279.223
# Validation Loss: 14333260.593
# Validation Accuracy: 0.579
#
#  Epoch 43 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 1139078549913.887
# Validation Loss: 14409235.714
# Validation Accuracy: 0.576
#
#  Epoch 44 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 1354537696302.224
# Validation Loss: 14468038.608
# Validation Accuracy: 0.577
#
#  Epoch 45 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 8688566485387.076
# Validation Loss: 14603421.308
# Validation Accuracy: 0.575
#
#  Epoch 46 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 5576051381501.675
# Validation Loss: 14574835.988
# Validation Accuracy: 0.578
#
#  Epoch 47 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 109471303611.914
# Validation Loss: 14521052.592
# Validation Accuracy: 0.577
#
#  Epoch 48 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 279561280706.386
# Validation Loss: 14566474.016
# Validation Accuracy: 0.577
#
#  Epoch 49 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 2355365432836.465
# Validation Loss: 14570585.999
# Validation Accuracy: 0.575
#
#  Epoch 50 / 50
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 2686795275464.040
# Validation Loss: 14534552.106
# Validation Accuracy: 0.579

# %%
y_val.to_numpy()

# %%
#plt.plot(train_losses)
plt.plot(valid_losses)
plt.legend(["train", "validation"])

# %%
loss, preds, acc = evaluate(model,test_dataloader, cross_entropy, test_data["label"])
print("test_accuracy:", acc)
