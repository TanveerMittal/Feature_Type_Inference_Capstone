# %%
# %load_ext autoreload
# %autoreload 2
import re
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import transformers
from transformers import AdamW
from transformers import AutoModel, BertTokenizerFast
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import sys
sys.path.append('../')
from process_data import *
from models.bert_cnn_v1 import *
from training import train
from evaluation import evaluate
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df_zoo_train, df_zoo_test = load_data("../data")
df_zoo_train.head()
# Out:
#    Record_id Attribute_name        y_act  total_vals  num_nans  %_nans  \
# 0         33           Area  categorical       21477         0     0.0
# 1         33      Area Code  categorical       21477         0     0.0
# 2         33        Element  categorical       21477         0     0.0
# 3         33   Element Code  categorical       21477         0     0.0
# 4         33           Item  categorical       21477         0     0.0
#
#    num_of_dist_val  %_dist_val         mean     std_dev  ...  \
# 0              174    0.810169     0.000000    0.000000  ...
# 1              174    0.810169   125.449411   72.866452  ...
# 2                2    0.009312     0.000000    0.000000  ...
# 3                2    0.009312  5211.687154  146.816661  ...
# 4              115    0.535457     0.000000    0.000000  ...
#
#    mean_stopword_total  stdev_stopword_total mean_char_count stdev_char_count  \
# 0                  0.2                   0.4            10.0         4.816638
# 1                  0.0                   0.0             1.0         0.000000
# 2                  0.0                   0.0             4.0         0.000000
# 3                  0.0                   0.0             4.0         0.000000
# 4                  0.8                   0.4            19.6         2.244994
#
#   mean_whitespace_count stdev_whitespace_count mean_delim_count  \
# 0                   0.4                    0.8              0.4
# 1                   0.0                    0.0              0.0
# 2                   0.0                    0.0              0.0
# 3                   0.0                    0.0              0.0
# 4                   2.0                    0.0              2.0
#
#    stdev_delim_count  is_list  is_long_sentence
# 0                0.8    False             False
# 1                0.0    False             False
# 2                0.0    False             False
# 3                0.0    False             False
# 4                0.0    False             False
#
# [5 rows x 33 columns]

# %%
train_data = preprocess_bert(df_zoo_train)
test_data = preprocess_bert(df_zoo_test)
train_data.head()
# Out:
#                                                 text  \
# 0  Area [SEP] Afghanistan [SEP] Albania [SEP] Alg...
# 1  Area Code [SEP] 2 [SEP] 3 [SEP] 4 [SEP] 7 [SEP] 8
# 2  Element [SEP] Food [SEP] Feed [SEP] Food [SEP]...
# 3  Element Code [SEP] 5142 [SEP] 5521 [SEP] 5142 ...
# 4  Item [SEP] Wheat and products [SEP] Rice (Mill...
#
#                                             features  label
# 0  [21477.0, 0.0, 0.0, 174.0, 0.810169018, 0.0, 0...      1
# 1  [21477.0, 0.0, 0.0, 174.0, 0.810169018, 125.44...      1
# 2  [21477.0, 0.0, 0.0, 2.0, 0.009312288, 0.0, 0.0...      1
# 3  [21477.0, 0.0, 0.0, 2.0, 0.009312288, 5211.687...      1
# 4  [21477.0, 0.0, 0.0, 115.0, 0.535456535, 0.0, 0...      1

# %%
x_train, x_val, y_train, y_val = train_test_split(train_data[['text', "features"]], train_data['label'], 
                                                                    random_state=2018, 
                                                                    test_size=0.2, 
                                                                    stratify=train_data['label'])

# %%
bert = AutoModel.from_pretrained('bert-base-uncased')

# Load the BERT tokenizer
tokenizer = BertTokenizerFast.from_pretrained('bert-base-uncased')
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
device = torch.device("cuda")

# %%
for param in bert.parameters():
    param.requires_grad = False

# %%
train_dataloader, val_dataloader, test_dataloader = init_dataloaders_bert(x_train, y_train, x_val, y_val, test_data)
# Out:
# /home/tamittal/.local/lib/python3.9/site-packages/transformers/tokenization_utils_base.py:2198: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(

# %%
class BERT_cnn(nn.Module):

    def __init__(self, bert, num_kernels, kernel_sizes):

        super(BERT_cnn, self).__init__()

        self.bert = bert 
    
        Co = num_kernels
        Ks = kernel_sizes
        
        self.convs1 = nn.ModuleList([nn.Conv2d(1, Co, (K, 768)) for K in Ks])
        self.dropout = nn.Dropout(0.1)
          
        # dropout layer
        self.dropout = nn.Dropout(0.1)

        # relu activation function
        self.relu =  nn.ReLU()

        # dense layer 1
        self.fc1 = nn.Linear(len(Ks) * Co + 25, 9)
        
        #softmax activation function
        self.softmax = nn.LogSoftmax(dim=1)

    #define the forward pass
    def forward(self, sent_id, mask, features):

        #pass the inputs to the model 
        bert_out = self.bert(sent_id, attention_mask=mask)
        
        x = bert_out.last_hidden_state
        
        x = x.unsqueeze(1)  # (N, Ci, W, D)

        x = [F.relu(conv(x)).squeeze(3) for conv in self.convs1]  # [(N, Co, W), ...]*len(Ks)

        x = [F.max_pool1d(i, i.size(2)).squeeze(2) for i in x]  
        
        x = torch.cat(x, 1)
        
        x = torch.cat([x, features], 1)
        
        x = self.dropout(x)  
        
        x = self.fc1(x)  
        
        x = self.softmax(x)

        return x

# %%
model = BERT_cnn(bert, 64, [3, 3, 3])

model = model.to(device)

# %%
for step,batch in enumerate(train_dataloader):
    batch = [r.to(device) for r in batch]
    sent_id, mask, features, labels = batch
    preds = model(sent_id, mask, features)
    break

# %%
# define the optimizer
optimizer = AdamW(model.parameters(),
                  lr = 1e-8)

# %%
from sklearn.utils.class_weight import compute_class_weight

#compute the class weights
class_weights = compute_class_weight('balanced', np.unique(y_train), y_train)
print("Class Weights:",class_weights)
# Out:
# Class Weights: [0.30349971 0.4756125  1.64413364 3.04022989 7.66666667 1.88088889
#  4.64035088 1.01050621 1.25281231]

# %%
weights= torch.tensor(class_weights,dtype=torch.float)
weights = weights.to(device)

# define the loss function
cross_entropy  = nn.NLLLoss(weight=weights) 

# number of training epochs
epochs = 25

# %%
# set initial loss to infinite
best_valid_loss = float('inf')

# empty lists to store training and validation loss of each epoch
train_losses=[]
valid_losses=[]

# %%
#for each epoch
for epoch in range(epochs):
     
    print('\n Epoch {:} / {:}'.format(epoch + 1, epochs))
    
    #train model
    train_loss, _, = train(model, train_dataloader, optimizer, cross_entropy)
    
    #evaluate model
    valid_loss, _, valid_acc = evaluate(model, val_dataloader, cross_entropy, y_val)
    
    #save the best model
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), 'saved_weights.pt')
    
    # append training and validation loss
    train_losses.append(train_loss)
    valid_losses.append(valid_loss)

    print(f'\nTraining Loss: {train_loss:.3f}')
    print(f'Validation Loss: {valid_loss:.3f}')
    print(f'Validation Accuracy: {valid_acc:.3f}')
# Out:
#  Epoch 1 / 25
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 12061808072421.850
# Validation Loss: 92603246.384
# Validation Accuracy: 0.632
#
#  Epoch 2 / 25
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 12281075275025.924
# Validation Loss: 92602780.289
# Validation Accuracy: 0.632
#
#  Epoch 3 / 25
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 13425612593613.543
# Validation Loss: 92599663.514
# Validation Accuracy: 0.631
#
#  Epoch 4 / 25
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 14764595462358.857
# Validation Loss: 92598177.912
# Validation Accuracy: 0.631
#
#  Epoch 5 / 25
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 14608957201668.283
# Validation Loss: 92596813.012
# Validation Accuracy: 0.631
#
#  Epoch 6 / 25
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 12436049341891.928
# Validation Loss: 92594462.254
# Validation Accuracy: 0.630
#
#  Epoch 7 / 25
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 8945829426393.949
# Validation Loss: 92592594.926
# Validation Accuracy: 0.630
#
#  Epoch 8 / 25
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 27719866010589.109
# Validation Loss: 92592557.158
# Validation Accuracy: 0.630
#
#  Epoch 9 / 25
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 19250803356077.074
# Validation Loss: 92588653.343
# Validation Accuracy: 0.630
#
#  Epoch 10 / 25
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 12921968989914.818
# Validation Loss: 92587954.307
# Validation Accuracy: 0.630
#
#  Epoch 11 / 25
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 10679665528149.576
# Validation Loss: 92585476.742
# Validation Accuracy: 0.630
#
#  Epoch 12 / 25
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 19244669495688.293
# Validation Loss: 92582982.688
# Validation Accuracy: 0.630
#
#  Epoch 13 / 25
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 26263000409135.059
# Validation Loss: 92581025.568
# Validation Accuracy: 0.630
#
#  Epoch 14 / 25
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 6142212493735.777
# Validation Loss: 92580737.101
# Validation Accuracy: 0.630
#
#  Epoch 15 / 25
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 30866149731601.734
# Validation Loss: 92577279.600
# Validation Accuracy: 0.630
#
#  Epoch 16 / 25
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 14230507894838.525
# Validation Loss: 92575601.059
# Validation Accuracy: 0.630
#
#  Epoch 17 / 25
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 8024998213156.087
# Validation Loss: 92573513.723
# Validation Accuracy: 0.630
#
#  Epoch 18 / 25
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 15612864958103.516
# Validation Loss: 92572591.339
# Validation Accuracy: 0.630
#
#  Epoch 19 / 25
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 16411872114532.869
# Validation Loss: 92569432.853
# Validation Accuracy: 0.630
#
#  Epoch 20 / 25
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 17369595092697.064
# Validation Loss: 92566989.537
# Validation Accuracy: 0.630
#
#  Epoch 21 / 25
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 9116940123091.662
# Validation Loss: 92564097.727
# Validation Accuracy: 0.630
#
#  Epoch 22 / 25
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 10270125734423.342
# Validation Loss: 92561125.327
# Validation Accuracy: 0.630
#
#  Epoch 23 / 25
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 16913348445350.324
# Validation Loss: 92561636.379
# Validation Accuracy: 0.630
#
#  Epoch 24 / 25
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 29845345487349.562
# Validation Loss: 92559207.380
# Validation Accuracy: 0.630
#
#  Epoch 25 / 25
#   Batch    50  of    199.
#   Batch   100  of    199.
#   Batch   150  of    199.
#
# Evaluating...
#
# Training Loss: 11777841210335.869
# Validation Loss: 92557795.571
# Validation Accuracy: 0.630

# %%
plt.plot(train_losses)
plt.plot(valid_losses)
plt.legend(["train", "validation"])

# %%
loss, preds, acc = evaluate(model,test_dataloader, cross_entropy, test_data["label"])
print("test_accuracy:", acc)
# Out:
# Evaluating...
#   Batch    50  of     63.
# test_accuracy: 0.6035264483627204
