# %%
import pandas as pd
from tabulate import tabulate

# %%
retrained_sampled_df = pd.read_csv('Retrained Sample Size Benchmark.csv', index_col=['Feature Type','Metric'])
retrained_sampled_df
# Out:
#                              Sameple Size: 1  Sameple Size: 2  \
# Feature Type      Metric
# numeric           accuracy          0.958690         0.956423
#                   precision         0.921727         0.916723
#                   recall            0.966054         0.965347
#                   f1-score          0.943370         0.940406
# categorical       accuracy          0.917380         0.919647
#                   precision         0.785575         0.801418
#                   recall            0.881838         0.865427
#                   f1-score          0.830928         0.832194
# datetime          accuracy          0.995970         0.996977
#                   precision         0.971631         0.968750
#                   recall            0.971631         0.989362
#                   f1-score          0.971631         0.978947
# sentence          accuracy          0.981360         0.981864
#                   precision         0.823529         0.811111
# ...

# %%
retrained_sampled_df = retrained_sampled_df.round(2)
retrained_sampled_df
# Out:
#                              Sameple Size: 1  Sameple Size: 2  \
# Feature Type      Metric
# numeric           accuracy              0.96             0.96
#                   precision             0.92             0.92
#                   recall                0.97             0.97
#                   f1-score              0.94             0.94
# categorical       accuracy              0.92             0.92
#                   precision             0.79             0.80
#                   recall                0.88             0.87
#                   f1-score              0.83             0.83
# datetime          accuracy              1.00             1.00
#                   precision             0.97             0.97
#                   recall                0.97             0.99
#                   f1-score              0.97             0.98
# sentence          accuracy              0.98             0.98
#                   precision             0.82             0.81
# ...

# %%
retrained_sampled_df.to_latex('Retrained Sample Size Benchmark.tex')

# %%
print(tabulate(retrained_sampled_df.reset_index(), tablefmt="pipe", headers="keys", showindex=False))
# Out:
# | Feature Type      | Metric    |   Sameple Size: 1 |   Sameple Size: 2 |   Sameple Size: 3 |   Sameple Size: 4 |   Sameple Size: 5 |   Sameple Size: 10 |
# |:------------------|:----------|------------------:|------------------:|------------------:|------------------:|------------------:|-------------------:|
# | numeric           | accuracy  |              0.96 |              0.96 |              0.96 |              0.96 |              0.96 |               0.96 |
# | numeric           | precision |              0.92 |              0.92 |              0.93 |              0.93 |              0.93 |               0.92 |
# | numeric           | recall    |              0.97 |              0.97 |              0.97 |              0.98 |              0.97 |               0.97 |
# | numeric           | f1-score  |              0.94 |              0.94 |              0.95 |              0.95 |              0.95 |               0.95 |
# ...
